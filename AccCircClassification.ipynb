# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
import numpy as np
import pandas as pd
from CprdatMethods import *
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
#os.chdir('')
caseno=''
dire=''
while not caseno in ['1','2','3','4','5']:
    print('Which case you want to load?')
    print('Please enter a number between 1 and 5!')
    caseno=input()
    dire='cc-periods_cases/Case_'+caseno+'/'

accel=pd.read_csv(dire+'Accelerometer.csv')
ecg=pd.read_csv(dire+'ShockElectrodes.csv')
co=pd.read_csv(dire+'Capnography.csv')
shocks=pd.read_csv(dire+'Defibrillations.csv',index_col=0)
physio=pd.read_csv(dire+'PhysioStatus.csv',index_col=0)
# Out:
# Which case you want to load?
# Please enter a number between 1 and 5!
# 2

# %%
data=collect_data(accel,ecg,co,shocks,physio)

# %%
erg=construct_data_for_snippets(data)
case_pred=predict_circulation(erg)

# %%
plot_circulation_predictions(data,case_pred)
# Out:
# /home/kernwo/Documents/Cardio/cardio_resuscitation/src/doc/Zenodo_upload/CprdatMethods.py:956: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
